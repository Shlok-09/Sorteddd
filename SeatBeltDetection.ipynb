# %% [markdown]
# <a href="https://colab.research.google.com/github/Shlok-09/Sorteddd/blob/main/SeatBeltDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15641, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 15641 (delta 125), reused 171 (delta 97), pack-reused 15393
# Receiving objects: 100% (15641/15641), 14.64 MiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (10653/10653), done.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import uuid
import time

# %%
# !unzip SeatBelt.zip -d SeatBelt
# Out:
# Archive:  SeatBelt.zip
#    creating: SeatBelt/SeatBelt/
#   inflating: SeatBelt/SeatBelt/labels.cache
#    creating: SeatBelt/SeatBelt/Train/
#    creating: SeatBelt/SeatBelt/Train/images/
#   inflating: SeatBelt/SeatBelt/Train/images/0EXVC0XIFMTG_jpg.rf.1fbc953640c9be93ee9e5102efeeb5c6.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/0FPT7JJNE5KE_jpg.rf.0494eba3d5083272929b8501e5af5ad9.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/0WQROGTRL8S4_jpg.rf.679cb694969252d7c7dca93d471efd26.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/0ZMZEJGO9VH2_jpg.rf.2605faac409d0e16852b89fba2615563.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/1OQ4026LAXXV_jpg.rf.aff6e5ec1f260fe1a9b724e675cc2627.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/1RIKVGY65SZV_jpg.rf.89b4f21d153ce41af6196deaa767c641.jpg
#   inflating: SeatBelt/SeatBelt/Train/images/1YLR172RDLM3_jpg.rf.a4f5574a2ab13f6ab256bfc8a93cfd8d.jpg
# ...

# %%
# !python /content/SeatBelt/SeatBelt/yolov5/train.py --img 320 --batch 32 --epochs 1 --data /content/SeatBelt/SeatBelt/yolov5/dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/SeatBelt/SeatBelt/yolov5/dataset.yaml, hyp=SeatBelt/SeatBelt/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=1, batch_size=32, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=SeatBelt/SeatBelt/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 2 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 2.96 KiB | 2.96 MiB/s, done.
# From https://github.com/ultralytics/yolov5
# ...

# %%
# !python /content/yolov5/train.py --img 640 --batch 32 --epochs 5 --data /content/yolov5/dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path = '/content/yolov5/runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-8 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# Fusing layers...
# ...

# %%
img1 = '/content/0FPT7JJNE5KE_jpg.rf.0494eba3d5083272929b8501e5af5ad9.jpg'
img2 = '/content/img_2023_jpg.rf.67c4ac761e4bbe8094c27c26c3a8adcc.jpg'

# %%
results2 = model(img2)
results2.print()
# Out:
# image 1/1: 640x640 1 seatbelt
# Speed: 35.0ms pre-process, 24.6ms inference, 8.4ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results2.render()))
plt.show()
